# %% [markdown]
# <a href="https://colab.research.google.com/github/Qudsia-jabeen20/Coronary_Disease/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel('/content/2.3.Categorical-variables.Visualization-techniques-lesson.xlsx')
df
# Out:
#    Unnamed: 0 Graphs and tables for categorical variables Unnamed: 2
# 0         NaN                             German car shop        NaN
# 1         NaN                                         NaN        NaN
# 2         NaN                                         NaN  Frequency
# 3         NaN                                        Audi        124
# 4         NaN                                         BMW         98
# 5         NaN                                    Mercedes        113
# 6         NaN                                       Total        335

# %%
df = pd.read_excel('/content/2.3.Categorical-variables.Visualization-techniques-lesson.xlsx', sheet_name='Pie chart' , usecols='B:C', skiprows=[0,1,2])
df
# Out:
#   Unnamed: 1  Frequency
# 0       Audi        124
# 1        BMW         98
# 2   Mercedes        113
# 3      Total        335

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.drop(3,axis=0, inplace=True)
df
# Out:
#   Unnamed: 1  Frequency
# 0       Audi        124
# 1        BMW         98
# 2   Mercedes        113

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
from matplotlib import pyplot as plt
plt.bar(x=df['Unnamed: 1'], height=df['Frequency'])
# Out:
# <BarContainer object of 3 artists>

# %%
df.plot.bar(x='Unnamed: 1', y='Frequency', rot=0, xlabel='')
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots()
p= ax.bar(x=df['Unnamed: 1'], height=df['Frequency'])
ax.bar_label(p, label_type='center')
# Out:
# [Text(0, 0, '124'), Text(0, 0, '98'), Text(0, 0, '113')]

# %%
df.plot.pie(y='Frequency')
# Out:
# <Axes: ylabel='Frequency'>

# %%
type(df.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
type(df['Unnamed: 1'])
# Out:
# pandas.core.series.Series

# %%
s= df['Unnamed: 1']
s
# Out:
# 0        Audi
# 1         BMW
# 2    Mercedes
# Name: Unnamed: 1, dtype: object

# %%
df.index=s
df
# Out:
#            Unnamed: 1  Frequency
# Unnamed: 1
# Audi             Audi        124
# BMW               BMW         98
# Mercedes     Mercedes        113

# %%
df.drop(['Unnamed: 1'], axis=1, inplace=True)
df
# Out:
#             Frequency
# Unnamed: 1
# Audi              124
# BMW                98
# Mercedes          113

# %%
df.iloc[:,0]
# Out:
# Unnamed: 1
# Audi        124
# BMW          98
# Mercedes    113
# Name: Frequency, dtype: int64

# %%
df.index.name=''
df
# Out:
#           Frequency
#
# Audi            124
# BMW              98
# Mercedes        113

# %%
df.plot.pie(y='Frequency', ylabel='', legend=False)
# Out:
# <Axes: >

# %%
df = pd.read_excel('/content/2.5.+The+Histogram_lesson.xlsx', usecols='B', skiprows=[0,1])
df
# Out:
#     Dataset
# 0         1
# 1         9
# 2        22
# 3        24
# 4        32
# 5        33
# 6        42
# 7        44
# 8        57
# 9        66
# 10       70
# 11       73
# 12       75
# 13       76
# 14       79
# 15       82
# 16       87
# 17       89
# 18       95
# 19      100

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist(bins=5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.hist(df, bins=5)
plt.show()
